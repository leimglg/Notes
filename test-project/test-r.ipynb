# %%
runif(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 runif(10)
#
# NameError: name 'runif' is not defined

# %%
plot(runif(10))
# Out:
# plot without title
